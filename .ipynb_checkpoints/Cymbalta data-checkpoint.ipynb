# %%
import numpy as np
import pandas as pd

reviews = pd.read_csv("cymbalta.csv")
reviews
# Out:
#                                                 comment  \
# 0     Fibromyalgia - taking 30 mg in the am, and 60 ...
# 1     resolved much of arthities in right hip, maybe...
# 2     I have used cymbalta for 8 yrs and it has work...
# 3                             Excellent, symptoms gone.
# 4     Totally changed my life for the better. Other ...
# 5     This medicine is horrible!  I can barely keep ...
# 6     This was the worst experience I have ever had ...
# 7     The 1st two weeks were the hardest. I have to ...
# 8     I have RA and Major Depression. Use drug for 1...
# 9     decreased radiating nerve pain as well as stif...
# 10    I have only been on it for 4 days now, I have ...
# 11    Terrible withdrawal while I am trying to taper...
# 12    Multiple Sclerosis left me with funny feat. Th...
# 13    I have been taking Lodine and major narcotics ...
# 14    The doctor prescribed Cymbalta for me for Chro...
# 15    I have a knee injury. I received nerve damage ...
# ...

# %%
reviews.shape
# Out:
# (4087, 7)

# %%
len(set(reviews.date))
# Out:
# 4087

# %%
set(reviews.condition)
# Out:
# {'\r\r\n\t\t\t\t\tCondition: Anxiousness associated with Depression',
#  '\r\r\n\t\t\t\t\tCondition: Chronic Muscle or Bone Pain',
#  '\r\r\n\t\t\t\t\tCondition: Diabetic Complication causing Injury to some Body Nerves',
#  '\r\r\n\t\t\t\t\tCondition: Disorder characterized by Stiff, Tender & Painful Muscles',
#  '\r\r\n\t\t\t\t\tCondition: Major Depressive Disorder',
#  '\r\r\n\t\t\t\t\tCondition: Neuropathic Pain',
#  '\r\r\n\t\t\t\t\tCondition: Other',
#  '\r\r\n\t\t\t\t\tCondition: Repeated Episodes of Anxiety'}

# %%
reviews.condition = reviews.condition.str.strip().replace('\r\r\n\t\t\t\t\tCondition:', '')

# %%
set(reviews.condition)
# Out:
# {'Anxiousness associated with Depression',
#  'Chronic Muscle or Bone Pain',
#  'Diabetic Complication causing Injury to some Body Nerves',
#  'Disorder characterized by Stiff, Tender & Painful Muscles',
#  'Major Depressive Disorder',
#  'Neuropathic Pain',
#  'Other',
#  'Repeated Episodes of Anxiety'}

# %%
reviews
# Out:
#                                                 comment  \
# 0     Fibromyalgia - taking 30 mg in the am, and 60 ...
# 1     resolved much of arthities in right hip, maybe...
# 2     I have used cymbalta for 8 yrs and it has work...
# 3                             Excellent, symptoms gone.
# 4     Totally changed my life for the better. Other ...
# 5     This medicine is horrible!  I can barely keep ...
# 6     This was the worst experience I have ever had ...
# 7     The 1st two weeks were the hardest. I have to ...
# 8     I have RA and Major Depression. Use drug for 1...
# 9     decreased radiating nerve pain as well as stif...
# 10    I have only been on it for 4 days now, I have ...
# 11    Terrible withdrawal while I am trying to taper...
# 12    Multiple Sclerosis left me with funny feat. Th...
# 13    I have been taking Lodine and major narcotics ...
# 14    The doctor prescribed Cymbalta for me for Chro...
# 15    I have a knee injury. I received nerve damage ...
# ...

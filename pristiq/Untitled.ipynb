# %%
import numpy as np
import pandas as pd

pris = pd.read_csv('pristiq.csv')
pris
# Out:
#                                               comment  \
# 0   Now on prestiq for three weeks or so, I've exp...
# 1                                         Brilliant.
# 2   I took this drug for almost two years. At firs...
# 3   I've been on Pristiq for over 5 years. No weig...
# 4   I've been taking 50 MG of Pristiq twice daily ...
# 5   Please if you're suffering from anxiety this d...
# 6   PTSD for 25 years from assault with serious in...
# 7   In my opinion, there is no antidepressant that...
# 8   *headaches. Effexor XR was the only antidepres...
# 9   I take 200mg ER at night so I can wake up in t...
# 10  I started on 50mg of Pristiq and the first wee...
# 11  I was placed on this medication after my insur...
# 12  This medication has saved my life. My main sid...
# 13  I've have terrible anxiety for as long as I ca...
# 14  Loss of appetite, headaches, inability to stay...
# 15  Therapist asked me to try Pristiq and so stopp...
# ...

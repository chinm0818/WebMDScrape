# %%
import numpy as np
import pandas as pd
effexor = pd.read_csv('effexor.csv')
effexor
# Out:
#                                                 comment  \
# 0     ve previously used Zoloft, Cipralex, Seroxat f...
# 1     I have taken effexor for 10-12 years.It is sti...
# 2     I still have anxiety, better controlled than w...
# 3     I have been on Effexor for 8 years now. It rea...
# 4     Effectiveness of Effexor XR (150 mg daily) for...
# 5     Leveled me out.  As others have stated, no hig...
# 6     I have general anxiety disorder and minor depr...
# 7     it helped me at first.But when it comes the ti...
# 8     I would caution those who are taking or increa...
# 9     while this drug works I found the side effects...
# 10    BESIDES MY BODY TRYING TO GET USED TO THE SIDE...
# 11    Terrible withdrawal. Neurological jolts aka br...
# 12                                                 okay
# 13    I was on Zoloft for about 10 years and during ...
# 14    Started this medicine in December of 2013 for ...
# 15    Can't get adjusted, have insomnia.  Having pan...
# ...

# %%
effexor.shape
# Out:
# (3047, 7)
